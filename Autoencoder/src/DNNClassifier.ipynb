# %% [markdown]
# # Implementing DNN classifier for Multi-Variable Time-Series

# %% [markdown]
# The csv file contains line examples with ${S_1}^{t-7}, ... , {S_1}^{t-0}, ... , {S_5}^{t-7}, ... , {S_5}^{t-0} , {S_1}^{t+5} $   being  $S_n$ time serie n and $t$ time step ($t-5$ - 5 time steps into the past)
#
# In resume :
# 35 inputs - 5 time-series with 7 time steps
# 1 output - (${S_1}^{t+5}$) first time serie 5 time steps ahead
#
# The output was categorized, using histogram technique, into 5 values :
# 0 - strong down
# 1 - weak down
# 2 - no movement
# 3 - weak up
# 5 - strong up

# %% [markdown]
# ### loading csv file

# %%
from __future__ import division, print_function, absolute_import

import tensorflow as tf
import logging
import pandas as pd
import tensorflow.contrib.learn as learn
import os
import shutil
import numpy as np
from sklearn import metrics
from sklearn.cross_validation import train_test_split
from tensorflow.python.framework import tensor_shape, graph_util
from tensorflow.python.platform import gfile
from tensorflow.python.saved_model import builder as saved_model_builder
from tensorflow.python.saved_model import tag_constants

# %%
print(tf.VERSION)
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# 1.1.0

# %%
def get_model_dir(name,erase):
    base_path = os.path.join(".","dnn")
    model_dir = os.path.join(base_path,name)
    os.makedirs(model_dir,exist_ok=True)
    if erase and len(model_dir)>4 and os.path.isdir(model_dir):
        shutil.rmtree(model_dir,ignore_errors=True) # be careful, this deletes everything below the specified path
    return model_dir

# %%
model_dir = get_model_dir('ModelSave',True)
classifier = learn.DNNClassifier(hidden_units=[10, 20, 5], n_classes=5
                                 ,feature_columns=feature_columns , model_dir= model_dir
                                 #,optimizer=tf.train.ProximalAdagradOptimizer(
                                 #     learning_rate=0.05,
                                 #     l1_regularization_strength=0.001
                                 )

# %%
df = pd.read_csv('../NNNormalizeData-out.csv')


inputs = []
target = []

y=0;    
for x in df.columns:
    if y != 35 :
        #print("added %d" %y)
        inputs.append(x)
    else :
        target.append(x)
    y+=1

total_inputs,total_output = df.as_matrix(inputs).astype(np.float32),df.as_matrix([target]).astype(np.int32)

train_inputs, test_inputs, train_output, test_output = train_test_split(total_inputs, total_output, test_size=0.2, random_state=42)

feature_columns = [tf.contrib.layers.real_valued_column("", dimension=train_inputs.shape[1])]
print (feature_columns)
# Out:
# [_RealValuedColumn(column_name='', dimension=35, default_value=None, dtype=tf.float32, normalizer=None)]

# %%
tf.logging.set_verbosity(tf.logging.INFO) # ts logging to normal 
logging.getLogger().setLevel(logging.INFO) # print train evolution
classifier.fit(train_inputs, train_output, steps=100)
#back to tf output only errors 
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# WARNING:tensorflow:From <ipython-input-29-ba2b9767596c>:3: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-29-ba2b9767596c>:3: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:loss = 1.62109, step = 1
# INFO:tensorflow:Saving checkpoints for 100 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.59106.

# %%
pred = list(classifier.predict(test_inputs, as_iterable=True))
score = metrics.accuracy_score(test_output, pred)
print("Final score: {}".format(score))
# Out:
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# Final score: 0.24698021074273965

# %% [markdown]
# # Ok is working now evolution using Early Stopping

# %%
import os
import shutil
import tensorflow as tf
import pandas as pd
import tensorflow.contrib.learn as learn
import numpy as np
from sklearn import metrics
from sklearn.cross_validation import train_test_split
from tensorflow.contrib import layers



def get_model_dir(name,erase):
    base_path = os.path.join(".","dnn")
    model_dir = os.path.join(base_path,name)
    os.makedirs(model_dir,exist_ok=True)
    if erase and len(model_dir)>4 and os.path.isdir(model_dir):
        shutil.rmtree(model_dir,ignore_errors=True) # be careful, this deletes everything below the specified path
    return model_dir


tf.logging.set_verbosity(tf.logging.INFO)

#save init (?)
#sess = tf.Session()
#sess.run(tf.global_variables_initializer())
#builder = tf.saved_model.builder.SavedModelBuilder("./model")
#sess.run(tf.global_variables_initializer())

print(tf.VERSION)


df = pd.read_csv('../NNNormalizeData-out.csv',header=None)

np.random.seed(42) # always shuffle the same way 
df = df.reindex(np.random.permutation(df.index)) # shuffle examples 
df.reset_index(inplace=True, drop=True)

inputs = []
target = []

y=0;    
for x in df.columns:
    if y != 35 :
        #print("added %d" %y)
        inputs.append(x)
    else :
        target.append(x)
    y+=1

total_inputs,total_output = df.as_matrix(inputs).astype(np.float32),df.as_matrix([target]).astype(np.int32)

train_inputs, test_inputs, train_output, test_output = train_test_split(total_inputs, total_output, test_size=0.2, random_state=42)

print("Total number of examples %d" %(total_inputs.shape[0]+1))
print("Train number of examples %d" %(train_inputs.shape[0]+1))
print("Test number of examples %d" %(test_inputs.shape[0]+1))




feature_columns = [tf.contrib.layers.real_valued_column("", dimension=train_inputs.shape[1])]
#target_column = [tf.contrib.layers.real_valued_column("output", dimension=train_output.shape[1])]
model_dir = get_model_dir('ModelSave',True)

training_steps = 40000
save_checkpoints_steps=400 # used to run the early stopping monitor 
early_stopping_rounds=2000   # after 50 SPETS if "loss" doesn't improve stop the train
batch_size=int((train_inputs.shape[0]+1)/20) # train number of examples / 10 - 10 batch = 1 epoch

classifier = learn.DNNClassifier(hidden_units=[100, 50, 20], n_classes=5
                                 ,model_dir= model_dir
                                 #,activation_fn=tf.nn.relu
                                 ,optimizer=tf.train.AdadeltaOptimizer(0.5)
                                 
                                 #,optimizer=tf.train.AdagradOptimizer(0.1)
                                 #tf.train.RMSPropOptimizer(learning_rate=0.1) #
                                 #tf.train.ProximalAdagradOptimizer(
                                 #     learning_rate=0.01)
                                 #     l1_regularization_strength=0.001
                                 #     )
                                 ,config=tf.contrib.learn.RunConfig(save_checkpoints_steps=save_checkpoints_steps
                                                                    ,save_checkpoints_secs=None)
                                 ,feature_columns=feature_columns)


#early stopping using validation monitor 
print("configuring early stopping")
validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
    x=test_inputs,
    y=test_output,
    #every_n_steps=200,  # when to run the monitor - not working - forcing with save_checkpoints_steps
    early_stopping_metric="accuracy",         #"accuracy" or "loss"
    early_stopping_metric_minimize=False,     #False Maximize accuracy (True is minimize applied to loss)  
    early_stopping_rounds=early_stopping_rounds)

print("Fit will start...")
#classifier = learn.SKCompat(classifier) # For Sklearn compatibility
classifier.fit(train_inputs, train_output, steps=training_steps , 
               batch_size=batch_size,
               monitors=[validation_monitor])
print("Fit is finish...")


#print (classifier.get_variable_names()) 

#Save Model into saved_model.pbtxt file (possible to Load in Java)
tfrecord_serving_input_fn = tf.contrib.learn.build_parsing_serving_input_fn(layers.create_feature_spec_for_parsing(feature_columns))  
classifier.export_savedmodel(export_dir_base="test", serving_input_fn = tfrecord_serving_input_fn,as_text=True)


# Measure accuracy
pred = list(classifier.predict(test_inputs, as_iterable=True))
#pred = list(classifier.predict(test_inputs))
score = metrics.accuracy_score(test_output, pred)
print("Final score: {}".format(score))

accuracy_score = classifier.evaluate(x=test_inputs,
                                     y=test_output)["accuracy"]

print('Accuracy: {0:f}'.format(accuracy_score))

# test individual samples 
sample_1 = np.array( [[0.37671986791414125,0.28395908337619136,-0.0966095873607713,-1.0,0.06891621389763203,-0.09716678086712205,0.726029084013637,4.984689881073479E-4,-0.30296253267499107,-0.16192917054985334,0.04820256230479658,0.4951319883569152,0.5269983894210499,-0.2560313828048315,-0.3710980821053321,-0.4845867212612598,-0.8647234314469595,-0.6491591208322198,-1.0,-0.5004549422844073,-0.9880910165770813,0.5540293108747256,0.5625990251930839,0.7420121698556554,0.5445551415657979,0.4644276850235627,0.7316976292340245,0.636690006814346,0.16486621649984112,-0.0466018967678159,0.5261100063227044,0.6256168612312738,-0.544295484930702,0.379125782517193,0.6959368575211544]], dtype=float)
sample_2 = np.array( [[1.0,0.7982741870963959,1.0,-0.46270838239235024,0.040320274521029376,0.443451913224413,-1.0,1.0,1.0,-1.0,0.36689718911339564,-0.13577379160035796,-0.5162916256414466,-0.03373651520104648,1.0,1.0,1.0,1.0,0.786999801054777,-0.43856035121103853,-0.8199093927945158,1.0,-1.0,-1.0,-0.1134921695894473,-1.0,0.6420892436196663,0.7871737734493178,1.0,0.6501788845358409,1.0,1.0,1.0,-0.17586627413625022,0.8817194210401085]], dtype=float)

pred = list(classifier.predict(sample_2, as_iterable=True))
print("Prediction for sample_2 is:{} ".format(pred))

pred = list(classifier.predict_proba(sample_2, as_iterable=True))
print("Prediction for sample_2 is:{} ".format(pred))
# Out:
# 1.1.0
# Total number of examples 19457
# Train number of examples 15565
# Test number of examples 3893
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f25231db6d8>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_save_checkpoints_steps': 400, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': None}
# configuring early stopping
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:267: BaseMonitor.__init__ (from tensorflow.contrib.learn.python.learn.monitors) is deprecated and will be removed after 2016-12-05.
# Instructions for updating:
# Monitors are deprecated. Please use tf.train.SessionRunHook.
# Fit will start...
# WARNING:tensorflow:From <ipython-input-31-f74050f9a54f>:101: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-31-f74050f9a54f>:101: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-31-f74050f9a54f>:101: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:loss = 1.63141, step = 1
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:44:37
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-1
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:44:38
# INFO:tensorflow:Saving dict for global step 1: accuracy = 0.21557, global_step = 1, loss = 1.61779
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 100): loss = 1.61779, accuracy = 0.21557, global_step = 1
# INFO:tensorflow:global_step/sec: 59.3189
# INFO:tensorflow:loss = 1.59265, step = 101 (1.691 sec)
# INFO:tensorflow:global_step/sec: 79.9787
# INFO:tensorflow:loss = 1.58526, step = 201 (1.247 sec)
# INFO:tensorflow:global_step/sec: 89.5518
# INFO:tensorflow:loss = 1.57716, step = 301 (1.117 sec)
# INFO:tensorflow:Saving checkpoints for 401 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 94.7919
# INFO:tensorflow:loss = 1.59615, step = 401 (1.055 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:44:42
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-401
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:44:42
# INFO:tensorflow:Saving dict for global step 401: accuracy = 0.250514, global_step = 401, loss = 1.58611
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 500): loss = 1.58611, accuracy = 0.250514, global_step = 401
# INFO:tensorflow:global_step/sec: 79.3304
# INFO:tensorflow:loss = 1.56622, step = 501 (1.260 sec)
# INFO:tensorflow:global_step/sec: 115.252
# INFO:tensorflow:loss = 1.57079, step = 601 (0.868 sec)
# INFO:tensorflow:global_step/sec: 116.408
# INFO:tensorflow:loss = 1.57284, step = 701 (0.859 sec)
# INFO:tensorflow:Saving checkpoints for 801 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 91.3072
# INFO:tensorflow:loss = 1.57696, step = 801 (1.097 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:44:46
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-801
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:44:47
# INFO:tensorflow:Saving dict for global step 801: accuracy = 0.261048, global_step = 801, loss = 1.57757
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 900): loss = 1.57757, accuracy = 0.261048, global_step = 801
# INFO:tensorflow:global_step/sec: 73.324
# INFO:tensorflow:loss = 1.57083, step = 901 (1.362 sec)
# INFO:tensorflow:global_step/sec: 107.026
# INFO:tensorflow:loss = 1.56149, step = 1001 (0.934 sec)
# INFO:tensorflow:global_step/sec: 114.981
# INFO:tensorflow:loss = 1.55749, step = 1101 (0.870 sec)
# INFO:tensorflow:Saving checkpoints for 1201 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 95.7103
# INFO:tensorflow:loss = 1.55927, step = 1201 (1.046 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:44:51
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-1201
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:44:51
# INFO:tensorflow:Saving dict for global step 1201: accuracy = 0.272354, global_step = 1201, loss = 1.57134
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1300): loss = 1.57134, accuracy = 0.272354, global_step = 1201
# INFO:tensorflow:global_step/sec: 71.3493
# INFO:tensorflow:loss = 1.54874, step = 1301 (1.400 sec)
# INFO:tensorflow:global_step/sec: 116.651
# INFO:tensorflow:loss = 1.55804, step = 1401 (0.858 sec)
# INFO:tensorflow:global_step/sec: 94.9118
# INFO:tensorflow:loss = 1.53989, step = 1501 (1.053 sec)
# INFO:tensorflow:Saving checkpoints for 1601 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 103.942
# INFO:tensorflow:loss = 1.55772, step = 1601 (0.962 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:44:55
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-1601
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:44:55
# INFO:tensorflow:Saving dict for global step 1601: accuracy = 0.279548, global_step = 1601, loss = 1.56498
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 1700): loss = 1.56498, accuracy = 0.279548, global_step = 1601
# INFO:tensorflow:global_step/sec: 79.4197
# INFO:tensorflow:loss = 1.64572, step = 1701 (1.259 sec)
# INFO:tensorflow:global_step/sec: 92.0157
# INFO:tensorflow:loss = 1.55129, step = 1801 (1.087 sec)
# INFO:tensorflow:global_step/sec: 106.02
# INFO:tensorflow:loss = 1.53806, step = 1901 (0.943 sec)
# INFO:tensorflow:Saving checkpoints for 2001 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 96.3071
# INFO:tensorflow:loss = 1.55384, step = 2001 (1.038 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:44:59
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-2001
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:44:59
# INFO:tensorflow:Saving dict for global step 2001: accuracy = 0.280319, global_step = 2001, loss = 1.55981
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 2100): loss = 1.55981, accuracy = 0.280319, global_step = 2001
# INFO:tensorflow:global_step/sec: 79.1627
# INFO:tensorflow:loss = 1.53212, step = 2101 (1.263 sec)
# INFO:tensorflow:global_step/sec: 91.6896
# INFO:tensorflow:loss = 1.51133, step = 2201 (1.091 sec)
# INFO:tensorflow:global_step/sec: 99.6083
# INFO:tensorflow:loss = 1.52817, step = 2301 (1.004 sec)
# INFO:tensorflow:Saving checkpoints for 2401 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 102.38
# INFO:tensorflow:loss = 1.51994, step = 2401 (0.977 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:04
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-2401
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:04
# INFO:tensorflow:Saving dict for global step 2401: accuracy = 0.29702, global_step = 2401, loss = 1.55371
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 2500): loss = 1.55371, accuracy = 0.29702, global_step = 2401
# INFO:tensorflow:global_step/sec: 70.1948
# INFO:tensorflow:loss = 1.53341, step = 2501 (1.424 sec)
# INFO:tensorflow:global_step/sec: 93.8402
# INFO:tensorflow:loss = 1.53028, step = 2601 (1.067 sec)
# INFO:tensorflow:global_step/sec: 103.96
# INFO:tensorflow:loss = 1.52175, step = 2701 (0.961 sec)
# INFO:tensorflow:Saving checkpoints for 2801 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 109.048
# INFO:tensorflow:loss = 1.49845, step = 2801 (0.917 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:08
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-2801
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:08
# INFO:tensorflow:Saving dict for global step 2801: accuracy = 0.296763, global_step = 2801, loss = 1.54907
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 2900): loss = 1.54907, accuracy = 0.296763, global_step = 2801
# INFO:tensorflow:global_step/sec: 78.4675
# INFO:tensorflow:loss = 1.51816, step = 2901 (1.275 sec)
# INFO:tensorflow:global_step/sec: 91.1639
# INFO:tensorflow:loss = 1.51254, step = 3001 (1.097 sec)
# INFO:tensorflow:global_step/sec: 101.334
# INFO:tensorflow:loss = 1.49693, step = 3101 (0.987 sec)
# INFO:tensorflow:Saving checkpoints for 3201 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 97.414
# INFO:tensorflow:loss = 1.48618, step = 3201 (1.027 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:12
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-3201
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:13
# INFO:tensorflow:Saving dict for global step 3201: accuracy = 0.304728, global_step = 3201, loss = 1.54206
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 3300): loss = 1.54206, accuracy = 0.304728, global_step = 3201
# INFO:tensorflow:global_step/sec: 75.1585
# INFO:tensorflow:loss = 1.50776, step = 3301 (1.332 sec)
# INFO:tensorflow:global_step/sec: 108.53
# INFO:tensorflow:loss = 1.51626, step = 3401 (0.920 sec)
# INFO:tensorflow:global_step/sec: 113.367
# INFO:tensorflow:loss = 1.49921, step = 3501 (0.882 sec)
# INFO:tensorflow:Saving checkpoints for 3601 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 95.9744
# INFO:tensorflow:loss = 1.50081, step = 3601 (1.043 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:16
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-3601
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:17
# INFO:tensorflow:Saving dict for global step 3601: accuracy = 0.307811, global_step = 3601, loss = 1.53641
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 3700): loss = 1.53641, accuracy = 0.307811, global_step = 3601
# INFO:tensorflow:global_step/sec: 82.411
# INFO:tensorflow:loss = 1.49094, step = 3701 (1.213 sec)
# INFO:tensorflow:global_step/sec: 117.295
# INFO:tensorflow:loss = 1.50048, step = 3801 (0.853 sec)
# INFO:tensorflow:global_step/sec: 116.075
# INFO:tensorflow:loss = 1.47988, step = 3901 (0.862 sec)
# INFO:tensorflow:Saving checkpoints for 4001 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 108.45
# INFO:tensorflow:loss = 1.4714, step = 4001 (0.922 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:20
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-4001
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:20
# INFO:tensorflow:Saving dict for global step 4001: accuracy = 0.31295, global_step = 4001, loss = 1.53147
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 4100): loss = 1.53147, accuracy = 0.31295, global_step = 4001
# INFO:tensorflow:global_step/sec: 85.2176
# INFO:tensorflow:loss = 1.47, step = 4101 (1.173 sec)
# INFO:tensorflow:global_step/sec: 118.223
# INFO:tensorflow:loss = 1.4828, step = 4201 (0.846 sec)
# INFO:tensorflow:global_step/sec: 116.166
# INFO:tensorflow:loss = 1.4705, step = 4301 (0.861 sec)
# INFO:tensorflow:Saving checkpoints for 4401 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 107.72
# INFO:tensorflow:loss = 1.46568, step = 4401 (0.928 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:24
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-4401
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:24
# INFO:tensorflow:Saving dict for global step 4401: accuracy = 0.317575, global_step = 4401, loss = 1.52645
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 4500): loss = 1.52645, accuracy = 0.317575, global_step = 4401
# INFO:tensorflow:global_step/sec: 86.6275
# INFO:tensorflow:loss = 1.46336, step = 4501 (1.154 sec)
# INFO:tensorflow:global_step/sec: 116.044
# INFO:tensorflow:loss = 1.46932, step = 4601 (0.862 sec)
# INFO:tensorflow:global_step/sec: 114.504
# INFO:tensorflow:loss = 1.45764, step = 4701 (0.873 sec)
# INFO:tensorflow:Saving checkpoints for 4801 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 109.174
# INFO:tensorflow:loss = 1.46726, step = 4801 (0.916 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:28
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-4801
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:28
# INFO:tensorflow:Saving dict for global step 4801: accuracy = 0.320915, global_step = 4801, loss = 1.52112
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 4900): loss = 1.52112, accuracy = 0.320915, global_step = 4801
# INFO:tensorflow:global_step/sec: 80.6865
# INFO:tensorflow:loss = 1.44842, step = 4901 (1.239 sec)
# INFO:tensorflow:global_step/sec: 118.189
# INFO:tensorflow:loss = 1.46136, step = 5001 (0.846 sec)
# INFO:tensorflow:global_step/sec: 111.525
# INFO:tensorflow:loss = 1.44561, step = 5101 (0.899 sec)
# INFO:tensorflow:Saving checkpoints for 5201 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 99.1683
# INFO:tensorflow:loss = 1.45828, step = 5201 (1.006 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:32
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-5201
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:32
# INFO:tensorflow:Saving dict for global step 5201: accuracy = 0.325797, global_step = 5201, loss = 1.51549
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 5300): loss = 1.51549, accuracy = 0.325797, global_step = 5201
# INFO:tensorflow:global_step/sec: 86.2993
# INFO:tensorflow:loss = 1.43437, step = 5301 (1.159 sec)
# INFO:tensorflow:global_step/sec: 114.519
# INFO:tensorflow:loss = 1.4379, step = 5401 (0.873 sec)
# INFO:tensorflow:global_step/sec: 114.854
# INFO:tensorflow:loss = 1.43196, step = 5501 (0.871 sec)
# INFO:tensorflow:Saving checkpoints for 5601 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 107.837
# INFO:tensorflow:loss = 1.42502, step = 5601 (0.928 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:36
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-5601
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:36
# INFO:tensorflow:Saving dict for global step 5601: accuracy = 0.331192, global_step = 5601, loss = 1.51098
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 5700): loss = 1.51098, accuracy = 0.331192, global_step = 5601
# INFO:tensorflow:global_step/sec: 80.3474
# INFO:tensorflow:loss = 1.4147, step = 5701 (1.244 sec)
# INFO:tensorflow:global_step/sec: 88.7889
# INFO:tensorflow:loss = 1.44658, step = 5801 (1.126 sec)
# INFO:tensorflow:global_step/sec: 50.2952
# INFO:tensorflow:loss = 1.47365, step = 5901 (1.997 sec)
# INFO:tensorflow:Saving checkpoints for 6001 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 39.0624
# INFO:tensorflow:loss = 1.40143, step = 6001 (2.554 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:45:43
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-6001
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:45:44
# INFO:tensorflow:Saving dict for global step 6001: accuracy = 0.334532, global_step = 6001, loss = 1.50743
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 6100): loss = 1.50743, accuracy = 0.334532, global_step = 6001
# INFO:tensorflow:global_step/sec: 50.9127
# INFO:tensorflow:loss = 1.41195, step = 6101 (1.962 sec)
# INFO:tensorflow:global_step/sec: 83.9794
# INFO:tensorflow:loss = 1.41037, step = 6201 (1.192 sec)
# INFO:tensorflow:global_step/sec: 44.6369
# INFO:tensorflow:loss = 1.42802, step = 6301 (2.262 sec)
# INFO:tensorflow:Saving checkpoints for 6401 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 56.1138
# INFO:tensorflow:loss = 1.41589, step = 6401 (1.759 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# ...
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:51:54
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-38401
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:51:54
# INFO:tensorflow:Saving dict for global step 38401: accuracy = 0.474306, global_step = 38401, loss = 1.45427
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 38500): loss = 1.45427, accuracy = 0.474306, global_step = 38401
# INFO:tensorflow:global_step/sec: 76.8408
# INFO:tensorflow:loss = 0.833945, step = 38501 (1.301 sec)
# INFO:tensorflow:global_step/sec: 118.217
# INFO:tensorflow:loss = 0.8232, step = 38601 (0.846 sec)
# INFO:tensorflow:global_step/sec: 88.9047
# INFO:tensorflow:loss = 0.853558, step = 38701 (1.128 sec)
# INFO:tensorflow:Saving checkpoints for 38801 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 50.5605
# INFO:tensorflow:loss = 0.831359, step = 38801 (1.974 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:51:59
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-38801
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:51:59
# INFO:tensorflow:Saving dict for global step 38801: accuracy = 0.473022, global_step = 38801, loss = 1.45278
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 38900): loss = 1.45278, accuracy = 0.473022, global_step = 38801
# INFO:tensorflow:global_step/sec: 76.5687
# INFO:tensorflow:loss = 0.838304, step = 38901 (1.306 sec)
# INFO:tensorflow:global_step/sec: 113.116
# INFO:tensorflow:loss = 0.833721, step = 39001 (0.884 sec)
# INFO:tensorflow:global_step/sec: 114.826
# INFO:tensorflow:loss = 0.832499, step = 39101 (0.871 sec)
# INFO:tensorflow:Saving checkpoints for 39201 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 107.177
# INFO:tensorflow:loss = 0.774674, step = 39201 (0.933 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:52:03
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-39201
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:52:03
# INFO:tensorflow:Saving dict for global step 39201: accuracy = 0.475077, global_step = 39201, loss = 1.45486
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 39300): loss = 1.45486, accuracy = 0.475077, global_step = 39201
# INFO:tensorflow:global_step/sec: 86.9825
# INFO:tensorflow:loss = 0.805213, step = 39301 (1.149 sec)
# INFO:tensorflow:global_step/sec: 115.911
# INFO:tensorflow:loss = 0.796059, step = 39401 (0.863 sec)
# INFO:tensorflow:global_step/sec: 115.995
# INFO:tensorflow:loss = 0.870503, step = 39501 (0.861 sec)
# INFO:tensorflow:Saving checkpoints for 39601 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:global_step/sec: 105.376
# INFO:tensorflow:loss = 0.840787, step = 39601 (0.950 sec)
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/monitors.py:662: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:52:07
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-39601
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:52:07
# INFO:tensorflow:Saving dict for global step 39601: accuracy = 0.479445, global_step = 39601, loss = 1.45624
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# INFO:tensorflow:Validation (step 39700): loss = 1.45624, accuracy = 0.479445, global_step = 39601
# INFO:tensorflow:global_step/sec: 86.4797
# INFO:tensorflow:loss = 0.803616, step = 39701 (1.156 sec)
# INFO:tensorflow:global_step/sec: 112.986
# INFO:tensorflow:loss = 0.793871, step = 39801 (0.886 sec)
# INFO:tensorflow:global_step/sec: 116.325
# INFO:tensorflow:loss = 0.80804, step = 39901 (0.860 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into ./dnn/ModelSave/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.762281.
# Fit is finish...
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py:1256: initialize_local_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.local_variables_initializer` instead.
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-40000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: b'test/1519663930/saved_model.pbtxt'
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:335: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:422: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-40000
# Final score: 0.4784172661870504
# WARNING:tensorflow:From <ipython-input-31-f74050f9a54f>:119: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-31-f74050f9a54f>:119: calling BaseEstimator.evaluate (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Starting evaluation at 2018-02-26-16:52:10
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-40000
# INFO:tensorflow:Finished evaluation at 2018-02-26-16:52:11
# INFO:tensorflow:Saving dict for global step 40000: accuracy = 0.478417, global_step = 40000, loss = 1.45809
# WARNING:tensorflow:Skipping summary for global_step, must be a float or np.float32.
# Accuracy: 0.478417
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:335: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:422: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-40000
# Prediction for sample_2 is:[1]
# WARNING:tensorflow:From /home/rjpg/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:457: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Restoring parameters from ./dnn/ModelSave/model.ckpt-40000
# Prediction for sample_2 is:[array([ 0.0710548 ,  0.54877216,  0.22201999,  0.13592854,  0.02222451], dtype=float32)]
