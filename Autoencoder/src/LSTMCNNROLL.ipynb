# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers.convolutional import Conv2D 
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.datasets import mnist
from keras.utils import np_utils
from keras.optimizers import SGD, RMSprop, Adam
import numpy as np
import pandas as pd
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard,ModelCheckpoint
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from sklearn.cross_validation import train_test_split
from keras.layers.wrappers import Bidirectional, TimeDistributed
from keras.layers import ConvLSTM2D,Input
from keras.models import Model
from keras.engine.topology import Layer,InputSpec
K.set_image_dim_ordering("th")
# Out:
# /home/rjpg/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/rjpg/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
sess = tf.Session()
K.set_session(sess)


dfin = pd.read_csv('../NNNormalizeDataIn.csv',header=None)  #inputs 128 lines per sample
dfout = pd.read_csv('../NNNormalizeDataOutClassses.csv',header=None)  #output classes 

#dfin=dfin.drop(dfin.columns[[2,3,4]], axis=1) #take some indicators out

NVARS=9

total_inputs,total_output = dfin.as_matrix().astype(np.float32),dfout.as_matrix().astype(np.int32)

print(total_inputs.shape)
print(total_output.shape)

print(total_inputs[0:128])



total_inputs = np.reshape(total_inputs, (-1,128,9))
print("######################################################")
print(total_inputs[0])
total_inputs = np.reshape(total_inputs, (-1,8,16,9))
print("######################################################")
print(total_inputs[0,7,15])
# Out:
# (265600, 9)
# (2075, 1)
# [[ 1.7088607e-01 -1.6782573e-01 -2.4510670e-01 ...  1.9872051e-01
#    3.2241258e-01  5.9588689e-01]
#  [ 1.0000000e+00  1.6732299e-01  1.1027586e-01 ...  1.9872051e-01
#    4.5077366e-01  5.0246048e-01]
#  [-1.6222519e-01  3.3489737e-01  3.8603857e-01 ...  1.9872051e-01
#    3.7737539e-01  3.8321662e-01]
#  ...
#  [ 4.3304465e-03 -2.5136155e-04 -4.0739995e-01 ...  9.8760493e-02
#    1.7321697e-01  3.5674417e-01]
#  [ 4.3304465e-03 -2.5136155e-04 -4.6310234e-01 ...  9.8760493e-02
#    2.4600889e-01  3.4299701e-01]
#  [-3.2878080e-01 -2.5136155e-04 -4.4819331e-01 ...  9.8760493e-02
#    9.8892011e-02  3.4476128e-01]]
# ######################################################
# [[ 1.7088607e-01 -1.6782573e-01 -2.4510670e-01 ...  1.9872051e-01
#    3.2241258e-01  5.9588689e-01]
#  [ 1.0000000e+00  1.6732299e-01  1.1027586e-01 ...  1.9872051e-01
#    4.5077366e-01  5.0246048e-01]
#  [-1.6222519e-01  3.3489737e-01  3.8603857e-01 ...  1.9872051e-01
#    3.7737539e-01  3.8321662e-01]
#  ...
#  [ 4.3304465e-03 -2.5136155e-04 -4.0739995e-01 ...  9.8760493e-02
#    1.7321697e-01  3.5674417e-01]
#  [ 4.3304465e-03 -2.5136155e-04 -4.6310234e-01 ...  9.8760493e-02
#    2.4600889e-01  3.4299701e-01]
#  [-3.2878080e-01 -2.5136155e-04 -4.4819331e-01 ...  9.8760493e-02
#    9.8892011e-02  3.4476128e-01]]
# ######################################################
# [-3.2878080e-01 -2.5136155e-04 -4.4819331e-01  8.4316647e-01
#   2.4594354e-02 -4.5017608e-02  9.8760493e-02  9.8892011e-02
#   3.4476128e-01]
# /home/rjpg/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   if sys.path[0] == '':

# %%
class CylindricalPadLSTMCNN2D(Layer):

    def __init__(self, m=0,n=1, **kwargs):
        super(CylindricalPadLSTMCNN2D, self).__init__(**kwargs)
        self.n = n
        self.m = m
        assert n > 0, 'n must be positive'
        
    def build(self, input_shape):
        self.input_spec = [InputSpec(shape=input_shape)]
        super(CylindricalPadLSTMCNN2D, self).build(input_shape)  
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)

    def get_output_shape_for(self, input_shape):
        return (input_shape[0],
                    input_shape[1],
                    input_shape[2],
                    input_shape[3] + 2*self.m,
                    input_shape[4] + 2*self.n)
    
    def call(self,testElement, mask=None):
        firstColumns=testElement[:,:,:,:,0:self.n]
        lastColumns=testElement[:,:,:,:,testElement.shape[4]-self.n:testElement.shape[4]]
        result=tf.concat([testElement,firstColumns], axis=4)
        result=tf.concat([lastColumns,result], axis=4)
        if self.m != 0 :
            #x = tf.placeholder(result.dtype, shape=[result.shape[0],result.shape[1],self.m,result.shape[3]])
            #y = tf.zeros_like(x,dtype=result.dtype)
            
            firstRows=result[:,:,:,0:self.m,:]
            
            y = tf.fill(tf.shape(firstRows), 0.)
            
            #y=tf.fill([result.shape[0],result.shape[1],self.m,result.shape[3]],0.)
            
            #y = tf.constant(0., shape=[result.shape[0],result.shape[1],self.m,result.shape[3]],dtype=result.dtype)
            result=tf.concat([y,result], axis=3)
            result=tf.concat([result,y], axis=3)
        
        return result

    def get_config(self):
        config = {'n': self.n,
        'm': self.m}
        base_config = super(CylindricalPadLSTMCNN2D, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

print("CylindricalPadLSTMCNN2D class layer defined")
# Out:
# CylindricalPadLSTMCNN2D class layer defined

# %%
def non_shuffling_train_test_split(X, y, test_size=0.2):
    i = int((1 - test_size) * X.shape[0]) + 1
    X_train, X_test = np.split(X, [i])
    y_train, y_test = np.split(y, [i])
    return X_train, X_test, y_train, y_test



train_inputs, test_inputs, train_output, test_output = non_shuffling_train_test_split(total_inputs, total_output, test_size=0.2)

print(train_inputs.shape)
print(train_output.shape)



import tensorflow as tf
from keras import backend as K
from keras.optimizers import Adam
from keras.utils import np_utils

NB_EPOCH = 500
# network and training
BATCH_SIZE = 64
VERBOSE = 1
OPTIMIZER = Adam()
VALIDATION_SPLIT=0.2

TIMESTEPS = 8
IMG_ROWS, IMG_COLS = 16, NVARS # input image dimensions
NB_CLASSES = 5  # number of outputs = number of classes
INPUT_SHAPE = (1, IMG_ROWS, IMG_COLS)

X_train = train_inputs[:,:, np.newaxis, :, :]
y_train = np_utils.to_categorical(train_output, NB_CLASSES)
X_test = test_inputs[:,:, np.newaxis, :, :]
y_test = np_utils.to_categorical(test_output, NB_CLASSES)

print(X_train.shape)


class convLSTMNet:
    @staticmethod
    def build(timeSteps,rows, cols,classes):
        #CONV=>POOL
        inputNet = Input(shape=(timeSteps,1,rows, cols)) #batch_shape=(20, 7, 5) 
        roll=CylindricalPadLSTMCNN2D(0,4)(inputNet)
        convlstm2d=Bidirectional(ConvLSTM2D(20, kernel_size=(4,9), padding="valid", dropout=0.3, recurrent_dropout=0.2,return_sequences=True))(roll)
        roll=CylindricalPadLSTMCNN2D(0,4)(convlstm2d)
        convlstm2d=Bidirectional(ConvLSTM2D(10, kernel_size=(6,9), padding="valid", dropout=0.3, recurrent_dropout=0.2))(roll)
        
        ##lstm=Bidirectional(LSTM(100,recurrent_dropout=0.4,dropout=0.4,return_sequences=True),merge_mode='concat')(inputNet) #worse using stateful=True
        
        #lstm=SeqSelfAttention(attention_activation='sigmoid')(lstm)
        
        ##lstm=Bidirectional(LSTM(50,recurrent_dropout=0.4,dropout=0.4,return_sequences=False),merge_mode='concat')(lstm) #worse using stateful=True 
        
        #classificationLayer=AttentionDecoder(150, classes)
        #lstm=LSTM(100,recurrent_dropout=0.4,dropout=0.4,return_sequences=True)(inputNet) #worse using stateful=True
        #lstm=LSTM(50,recurrent_dropout=0.4,dropout=0.4)(lstm) #worse using stateful=True 
        
        
        #denselayers=Dense(400)(lstm)
        #denselayers=Activation("relu")(denselayers)
        #denselayers=Dropout(0.5)(denselayers)
        #denselayers=Dense(150)(denselayers)
        #denselayers=Activation("relu")(denselayers)
        #denselayers=Dropout(0.8)(denselayers)
        # a softmax classifier
        lstm=Flatten()(convlstm2d)
        dense=Dense(100,activation="relu")(lstm)
        dense=Dropout(0.5)(dense)
        dense=Dense(50,activation="relu")(dense)
        dense=Dropout(0.5)(dense)
        classificationLayer=Dense(classes,activation='softmax')(dense)
        
        #classificationLayer=Activation("softmax")(classificationLayer)
        
        model=Model(inputNet,classificationLayer)
        return model
    
modellstm = convLSTMNet.build(timeSteps=8,rows=16, cols=NVARS,classes=5)
modellstm.summary()
modellstm.compile(loss="categorical_crossentropy", optimizer=OPTIMIZER,
    metrics=["accuracy"])


# Prepare saver.
#builder = tf.saved_model.builder.SavedModelBuilder("./model_keras")

# Initialize all variables
sess.run(tf.global_variables_initializer())
# Out:
# (1661, 8, 16, 9)
# (1661, 1)
# (1661, 8, 1, 16, 9)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 8, 1, 16, 9)       0
# _________________________________________________________________
# cylindrical_pad_lstmcn_n2d_3 (None, 8, 1, 16, 17)      0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 8, 20, 13, 18)     121120
# _________________________________________________________________
# cylindrical_pad_lstmcn_n2d_4 (None, 8, 20, 13, 26)     0
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 10, 8, 36)         129680
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2880)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               288100
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 544,205
# Trainable params: 544,205
# Non-trainable params: 0
# _________________________________________________________________

# %%
tbCallBack = TensorBoard(log_dir='./Graph', histogram_freq=0, write_graph=True, write_images=True)
esCallBack = EarlyStopping(monitor='val_acc', min_delta=2, patience=50, verbose=0, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.2,patience=5, min_lr=0.001)
best_checkpoint = ModelCheckpoint('lstmCÑNROLL_new_data.h5', monitor='val_acc', save_best_only=True, verbose=1)



history = modellstm.fit(X_train, y_train, 
        batch_size=BATCH_SIZE, epochs=NB_EPOCH, 
        verbose=2, # 0 for no logging to stdout, 1 for progress bar logging, 2 for one log line per epoch.
        #validation_split=VALIDATION_SPLIT,
        validation_data=(X_test,y_test),
        callbacks=[tbCallBack,best_checkpoint])#,reduce_lr,esCallBack])
# Out:
# Train on 1661 samples, validate on 414 samples
# Epoch 1/500
#  - 12s - loss: 1.6133 - acc: 0.2089 - val_loss: 1.6086 - val_acc: 0.2150
#
# Epoch 00001: val_acc improved from -inf to 0.21498, saving model to lstmCÑNROLL_new_data.h5
# Epoch 2/500
#  - 7s - loss: 1.6131 - acc: 0.2053 - val_loss: 1.6103 - val_acc: 0.2126
#
# Epoch 00002: val_acc did not improve from 0.21498
# Epoch 3/500
#  - 7s - loss: 1.6077 - acc: 0.2264 - val_loss: 1.6099 - val_acc: 0.1981
#
# Epoch 00003: val_acc did not improve from 0.21498
# Epoch 4/500
#  - 7s - loss: 1.6082 - acc: 0.2312 - val_loss: 1.6114 - val_acc: 0.2319
#
# Epoch 00004: val_acc improved from 0.21498 to 0.23188, saving model to lstmCÑNROLL_new_data.h5
# Epoch 5/500
#  - 7s - loss: 1.6103 - acc: 0.2059 - val_loss: 1.6085 - val_acc: 0.2174
#
# Epoch 00005: val_acc did not improve from 0.23188
# Epoch 6/500
#  - 7s - loss: 1.6022 - acc: 0.2384 - val_loss: 1.6108 - val_acc: 0.1957
#
# Epoch 00006: val_acc did not improve from 0.23188
# Epoch 7/500
#  - 7s - loss: 1.6023 - acc: 0.2300 - val_loss: 1.6035 - val_acc: 0.2367
#
# Epoch 00007: val_acc improved from 0.23188 to 0.23671, saving model to lstmCÑNROLL_new_data.h5
# Epoch 8/500
#  - 7s - loss: 1.6024 - acc: 0.2252 - val_loss: 1.6037 - val_acc: 0.2319
#
# Epoch 00008: val_acc did not improve from 0.23671
# Epoch 9/500
#  - 7s - loss: 1.5908 - acc: 0.2402 - val_loss: 1.6039 - val_acc: 0.2343
#
# Epoch 00009: val_acc did not improve from 0.23671
# Epoch 10/500
#  - 7s - loss: 1.5995 - acc: 0.2312 - val_loss: 1.6046 - val_acc: 0.2367
#
# Epoch 00010: val_acc did not improve from 0.23671
# Epoch 11/500
#  - 7s - loss: 1.5890 - acc: 0.2498 - val_loss: 1.6045 - val_acc: 0.2391
#
# Epoch 00011: val_acc improved from 0.23671 to 0.23913, saving model to lstmCÑNROLL_new_data.h5
# Epoch 12/500
#  - 7s - loss: 1.5961 - acc: 0.2342 - val_loss: 1.6152 - val_acc: 0.2271
#
# Epoch 00012: val_acc did not improve from 0.23913
# Epoch 13/500
#  - 7s - loss: 1.5820 - acc: 0.2595 - val_loss: 1.6063 - val_acc: 0.2222
#
# Epoch 00013: val_acc did not improve from 0.23913
# Epoch 14/500
#  - 7s - loss: 1.5853 - acc: 0.2763 - val_loss: 1.6035 - val_acc: 0.2271
#
# Epoch 00014: val_acc did not improve from 0.23913
# Epoch 15/500
#  - 7s - loss: 1.5802 - acc: 0.2709 - val_loss: 1.6104 - val_acc: 0.2053
#
# Epoch 00015: val_acc did not improve from 0.23913
# Epoch 16/500
#  - 7s - loss: 1.5820 - acc: 0.2673 - val_loss: 1.6062 - val_acc: 0.2150
#
# Epoch 00016: val_acc did not improve from 0.23913
# Epoch 17/500
#  - 7s - loss: 1.5774 - acc: 0.2860 - val_loss: 1.6072 - val_acc: 0.2319
#
# Epoch 00017: val_acc did not improve from 0.23913
# Epoch 18/500
#  - 7s - loss: 1.5610 - acc: 0.2884 - val_loss: 1.6074 - val_acc: 0.2440
#
# Epoch 00018: val_acc improved from 0.23913 to 0.24396, saving model to lstmCÑNROLL_new_data.h5
# Epoch 19/500
#  - 7s - loss: 1.5619 - acc: 0.2733 - val_loss: 1.6047 - val_acc: 0.2343
#
# Epoch 00019: val_acc did not improve from 0.24396
# Epoch 20/500
#  - 7s - loss: 1.5572 - acc: 0.2956 - val_loss: 1.6025 - val_acc: 0.2391
#
# Epoch 00020: val_acc did not improve from 0.24396
# Epoch 21/500
#  - 7s - loss: 1.5576 - acc: 0.2860 - val_loss: 1.6035 - val_acc: 0.2633
#
# Epoch 00021: val_acc improved from 0.24396 to 0.26329, saving model to lstmCÑNROLL_new_data.h5
# Epoch 22/500
#  - 7s - loss: 1.5387 - acc: 0.3070 - val_loss: 1.6173 - val_acc: 0.2101
#
# Epoch 00022: val_acc did not improve from 0.26329
# Epoch 23/500
#  - 7s - loss: 1.5385 - acc: 0.3203 - val_loss: 1.6083 - val_acc: 0.2319
#
# Epoch 00023: val_acc did not improve from 0.26329
# Epoch 24/500
#  - 7s - loss: 1.5288 - acc: 0.3203 - val_loss: 1.6041 - val_acc: 0.2271
#
# Epoch 00024: val_acc did not improve from 0.26329
# Epoch 25/500
#  - 7s - loss: 1.5274 - acc: 0.3089 - val_loss: 1.6119 - val_acc: 0.2319
#
# Epoch 00025: val_acc did not improve from 0.26329
# Epoch 26/500
#  - 7s - loss: 1.5090 - acc: 0.3371 - val_loss: 1.6079 - val_acc: 0.2367
#
# Epoch 00026: val_acc did not improve from 0.26329
# Epoch 27/500
#  - 7s - loss: 1.5095 - acc: 0.3365 - val_loss: 1.6105 - val_acc: 0.2464
#
# Epoch 00027: val_acc did not improve from 0.26329
# Epoch 28/500
#  - 7s - loss: 1.4907 - acc: 0.3353 - val_loss: 1.6139 - val_acc: 0.2512
#
# Epoch 00028: val_acc did not improve from 0.26329
# Epoch 29/500
#  - 7s - loss: 1.4795 - acc: 0.3480 - val_loss: 1.6076 - val_acc: 0.2681
#
# Epoch 00029: val_acc improved from 0.26329 to 0.26812, saving model to lstmCÑNROLL_new_data.h5
# Epoch 30/500
#  - 7s - loss: 1.4777 - acc: 0.3516 - val_loss: 1.6266 - val_acc: 0.2633
#
# Epoch 00030: val_acc did not improve from 0.26812
# Epoch 31/500
#  - 7s - loss: 1.4616 - acc: 0.3679 - val_loss: 1.6258 - val_acc: 0.2198
#
# Epoch 00031: val_acc did not improve from 0.26812
# Epoch 32/500
#  - 7s - loss: 1.4374 - acc: 0.3709 - val_loss: 1.6265 - val_acc: 0.2488
#
# Epoch 00032: val_acc did not improve from 0.26812
# Epoch 33/500
#  - 7s - loss: 1.4507 - acc: 0.3739 - val_loss: 1.6217 - val_acc: 0.2367
#
# Epoch 00033: val_acc did not improve from 0.26812
# Epoch 34/500
#  - 7s - loss: 1.4321 - acc: 0.3739 - val_loss: 1.6383 - val_acc: 0.2488
#
# Epoch 00034: val_acc did not improve from 0.26812
# Epoch 35/500
#  - 7s - loss: 1.4288 - acc: 0.3937 - val_loss: 1.6255 - val_acc: 0.2609
#
# Epoch 00035: val_acc did not improve from 0.26812
# Epoch 36/500
#  - 7s - loss: 1.3875 - acc: 0.4106 - val_loss: 1.6328 - val_acc: 0.2319
#
# Epoch 00036: val_acc did not improve from 0.26812
# Epoch 37/500
#  - 7s - loss: 1.3817 - acc: 0.3980 - val_loss: 1.6678 - val_acc: 0.2246
#
# Epoch 00037: val_acc did not improve from 0.26812
# Epoch 38/500
#  - 7s - loss: 1.3808 - acc: 0.4052 - val_loss: 1.6374 - val_acc: 0.2150
#
# Epoch 00038: val_acc did not improve from 0.26812
# Epoch 39/500
#  - 7s - loss: 1.3489 - acc: 0.4262 - val_loss: 1.6626 - val_acc: 0.2536
#
# Epoch 00039: val_acc did not improve from 0.26812
# Epoch 40/500
#  - 7s - loss: 1.3096 - acc: 0.4582 - val_loss: 1.6840 - val_acc: 0.2512
#
# Epoch 00040: val_acc did not improve from 0.26812
# Epoch 41/500
#  - 7s - loss: 1.3086 - acc: 0.4557 - val_loss: 1.7439 - val_acc: 0.2464
#
# Epoch 00041: val_acc did not improve from 0.26812
# Epoch 42/500
#  - 7s - loss: 1.2808 - acc: 0.4883 - val_loss: 1.7716 - val_acc: 0.2271
#
# Epoch 00042: val_acc did not improve from 0.26812
# Epoch 43/500
#  - 7s - loss: 1.2780 - acc: 0.4816 - val_loss: 1.7341 - val_acc: 0.2174
#
# Epoch 00043: val_acc did not improve from 0.26812
# Epoch 44/500
#  - 7s - loss: 1.2484 - acc: 0.4865 - val_loss: 1.7899 - val_acc: 0.2174
#
# Epoch 00044: val_acc did not improve from 0.26812
# Epoch 45/500
#  - 7s - loss: 1.2164 - acc: 0.4943 - val_loss: 1.8058 - val_acc: 0.2464
#
# Epoch 00045: val_acc did not improve from 0.26812
# Epoch 46/500
#  - 7s - loss: 1.1987 - acc: 0.5081 - val_loss: 1.8250 - val_acc: 0.2536
#
# Epoch 00046: val_acc did not improve from 0.26812
# Epoch 47/500
#  - 7s - loss: 1.2000 - acc: 0.5135 - val_loss: 1.7821 - val_acc: 0.2657
#
# Epoch 00047: val_acc did not improve from 0.26812
# Epoch 48/500
#  - 7s - loss: 1.1727 - acc: 0.5190 - val_loss: 1.8564 - val_acc: 0.2657
#
# Epoch 00048: val_acc did not improve from 0.26812
# Epoch 49/500
#  - 7s - loss: 1.1345 - acc: 0.5334 - val_loss: 1.8588 - val_acc: 0.2609
#
# Epoch 00049: val_acc did not improve from 0.26812
# Epoch 50/500
#  - 7s - loss: 1.1087 - acc: 0.5689 - val_loss: 1.8748 - val_acc: 0.2464
#
# Epoch 00050: val_acc did not improve from 0.26812
# Epoch 51/500
#  - 7s - loss: 1.0867 - acc: 0.5587 - val_loss: 1.9828 - val_acc: 0.2415
#
# Epoch 00051: val_acc did not improve from 0.26812
# Epoch 52/500
#  - 7s - loss: 1.0670 - acc: 0.5750 - val_loss: 1.9200 - val_acc: 0.2464
#
# Epoch 00052: val_acc did not improve from 0.26812
# Epoch 53/500
#  - 7s - loss: 1.0939 - acc: 0.5611 - val_loss: 1.9133 - val_acc: 0.2488
#
# Epoch 00053: val_acc did not improve from 0.26812
# Epoch 54/500
#  - 7s - loss: 1.0333 - acc: 0.5942 - val_loss: 1.9845 - val_acc: 0.2464
#
# Epoch 00054: val_acc did not improve from 0.26812
# Epoch 55/500
#  - 7s - loss: 0.9831 - acc: 0.6279 - val_loss: 1.9743 - val_acc: 0.2391
#
# Epoch 00055: val_acc did not improve from 0.26812
# Epoch 56/500
#  - 7s - loss: 0.9995 - acc: 0.6141 - val_loss: 2.0537 - val_acc: 0.2391
#
# Epoch 00056: val_acc did not improve from 0.26812
# Epoch 57/500
#  - 7s - loss: 0.9250 - acc: 0.6490 - val_loss: 2.1607 - val_acc: 0.2391
#
# Epoch 00057: val_acc did not improve from 0.26812
# Epoch 58/500
#  - 7s - loss: 0.9533 - acc: 0.6394 - val_loss: 2.0446 - val_acc: 0.2271
#
# Epoch 00058: val_acc did not improve from 0.26812
# Epoch 59/500
#  - 7s - loss: 0.9253 - acc: 0.6436 - val_loss: 2.0763 - val_acc: 0.2560
#
# Epoch 00059: val_acc did not improve from 0.26812
# Epoch 60/500
#  - 7s - loss: 0.9134 - acc: 0.6550 - val_loss: 2.0987 - val_acc: 0.2440
#
# Epoch 00060: val_acc did not improve from 0.26812
# Epoch 61/500
#  - 7s - loss: 0.8768 - acc: 0.6791 - val_loss: 2.1208 - val_acc: 0.2536
#
# Epoch 00061: val_acc did not improve from 0.26812
# Epoch 62/500
#  - 7s - loss: 0.8492 - acc: 0.6875 - val_loss: 2.3499 - val_acc: 0.2367
#
# Epoch 00062: val_acc did not improve from 0.26812
# Epoch 63/500
#  - 7s - loss: 0.8458 - acc: 0.6785 - val_loss: 2.1496 - val_acc: 0.2464
#
# Epoch 00063: val_acc did not improve from 0.26812
# Epoch 64/500
#  - 7s - loss: 0.7946 - acc: 0.6893 - val_loss: 2.5086 - val_acc: 0.2271
#
# Epoch 00064: val_acc did not improve from 0.26812
# Epoch 65/500
#  - 7s - loss: 0.7764 - acc: 0.6954 - val_loss: 2.3055 - val_acc: 0.2319
#
# Epoch 00065: val_acc did not improve from 0.26812
# Epoch 66/500
#  - 7s - loss: 0.8115 - acc: 0.6978 - val_loss: 2.2739 - val_acc: 0.2295
#
# Epoch 00066: val_acc did not improve from 0.26812
# Epoch 67/500
#  - 7s - loss: 0.7852 - acc: 0.7086 - val_loss: 2.2841 - val_acc: 0.2295
#
# Epoch 00067: val_acc did not improve from 0.26812
# Epoch 68/500
#  - 7s - loss: 0.7161 - acc: 0.7273 - val_loss: 2.5789 - val_acc: 0.2512
#
# Epoch 00068: val_acc did not improve from 0.26812
# Epoch 69/500
#  - 7s - loss: 0.7523 - acc: 0.7200 - val_loss: 2.4264 - val_acc: 0.2512
#
# Epoch 00069: val_acc did not improve from 0.26812
# Epoch 70/500
#  - 7s - loss: 0.7500 - acc: 0.7188 - val_loss: 2.4521 - val_acc: 0.2319
#
# Epoch 00070: val_acc did not improve from 0.26812
# Epoch 71/500
#  - 7s - loss: 0.6853 - acc: 0.7447 - val_loss: 2.5839 - val_acc: 0.2198
#
# Epoch 00071: val_acc did not improve from 0.26812
# Epoch 72/500
#  - 7s - loss: 0.6333 - acc: 0.7676 - val_loss: 2.6288 - val_acc: 0.2512
#
# Epoch 00072: val_acc did not improve from 0.26812
# Epoch 73/500
#  - 7s - loss: 0.6372 - acc: 0.7718 - val_loss: 2.7765 - val_acc: 0.2440
#
# Epoch 00073: val_acc did not improve from 0.26812
# Epoch 74/500
#  - 7s - loss: 0.6884 - acc: 0.7357 - val_loss: 2.4103 - val_acc: 0.2488
#
# Epoch 00074: val_acc did not improve from 0.26812
# Epoch 75/500
#  - 7s - loss: 0.6323 - acc: 0.7766 - val_loss: 2.5835 - val_acc: 0.2126
#
# Epoch 00075: val_acc did not improve from 0.26812
# Epoch 76/500
#  - 7s - loss: 0.6094 - acc: 0.7857 - val_loss: 2.6308 - val_acc: 0.2319
#
# Epoch 00076: val_acc did not improve from 0.26812
# Epoch 77/500
#  - 7s - loss: 0.5869 - acc: 0.7778 - val_loss: 2.7907 - val_acc: 0.2536
#
# Epoch 00077: val_acc did not improve from 0.26812
# Epoch 78/500
#  - 7s - loss: 0.5925 - acc: 0.7736 - val_loss: 2.5891 - val_acc: 0.2440
#
# Epoch 00078: val_acc did not improve from 0.26812
# Epoch 79/500
#  - 7s - loss: 0.6283 - acc: 0.7634 - val_loss: 2.6908 - val_acc: 0.2609
#
# Epoch 00079: val_acc did not improve from 0.26812
# Epoch 80/500
#  - 7s - loss: 0.5980 - acc: 0.7863 - val_loss: 2.6751 - val_acc: 0.2488
#
# Epoch 00080: val_acc did not improve from 0.26812
# Epoch 81/500
#  - 7s - loss: 0.5860 - acc: 0.7971 - val_loss: 2.6781 - val_acc: 0.2633
#
# Epoch 00081: val_acc did not improve from 0.26812
# Epoch 82/500
#  - 7s - loss: 0.5577 - acc: 0.8037 - val_loss: 2.7815 - val_acc: 0.2367
#
# Epoch 00082: val_acc did not improve from 0.26812
# Epoch 83/500
#  - 7s - loss: 0.5747 - acc: 0.7941 - val_loss: 2.7060 - val_acc: 0.2246
#
# Epoch 00083: val_acc did not improve from 0.26812
# Epoch 84/500
#  - 7s - loss: 0.5640 - acc: 0.7989 - val_loss: 2.7524 - val_acc: 0.2464
#
# Epoch 00084: val_acc did not improve from 0.26812
# Epoch 85/500
#  - 7s - loss: 0.5482 - acc: 0.8013 - val_loss: 2.8176 - val_acc: 0.2295
#
# Epoch 00085: val_acc did not improve from 0.26812
# Epoch 86/500
#  - 7s - loss: 0.5266 - acc: 0.8140 - val_loss: 2.8341 - val_acc: 0.2271
#
# Epoch 00086: val_acc did not improve from 0.26812
# Epoch 87/500
#  - 7s - loss: 0.5007 - acc: 0.8290 - val_loss: 2.9719 - val_acc: 0.2440
#
# Epoch 00087: val_acc did not improve from 0.26812
# Epoch 88/500
#  - 7s - loss: 0.4740 - acc: 0.8296 - val_loss: 3.0911 - val_acc: 0.2295
#
# Epoch 00088: val_acc did not improve from 0.26812
# Epoch 89/500
#  - 7s - loss: 0.4960 - acc: 0.8242 - val_loss: 3.0816 - val_acc: 0.2246
#
# Epoch 00089: val_acc did not improve from 0.26812
# Epoch 90/500
#  - 7s - loss: 0.5003 - acc: 0.8176 - val_loss: 2.9330 - val_acc: 0.2174
#
# Epoch 00090: val_acc did not improve from 0.26812
# Epoch 91/500
#  - 7s - loss: 0.4612 - acc: 0.8350 - val_loss: 3.0199 - val_acc: 0.2246
#
# Epoch 00091: val_acc did not improve from 0.26812
# Epoch 92/500
#  - 7s - loss: 0.4611 - acc: 0.8387 - val_loss: 2.9417 - val_acc: 0.2415
#
# Epoch 00092: val_acc did not improve from 0.26812
# Epoch 93/500
#  - 7s - loss: 0.4500 - acc: 0.8362 - val_loss: 3.1112 - val_acc: 0.2271
#
# Epoch 00093: val_acc did not improve from 0.26812
# Epoch 94/500
#  - 7s - loss: 0.4532 - acc: 0.8489 - val_loss: 3.0266 - val_acc: 0.2367
#
# Epoch 00094: val_acc did not improve from 0.26812
# Epoch 95/500
#  - 7s - loss: 0.4639 - acc: 0.8447 - val_loss: 3.1590 - val_acc: 0.2609
#
# Epoch 00095: val_acc did not improve from 0.26812
# Epoch 96/500
#  - 7s - loss: 0.4253 - acc: 0.8507 - val_loss: 3.1780 - val_acc: 0.2440
#
# Epoch 00096: val_acc did not improve from 0.26812
# Epoch 97/500
#  - 7s - loss: 0.4368 - acc: 0.8531 - val_loss: 3.2732 - val_acc: 0.2391
#
# Epoch 00097: val_acc did not improve from 0.26812
# Epoch 98/500
#  - 7s - loss: 0.4177 - acc: 0.8549 - val_loss: 3.2748 - val_acc: 0.2633
#
# Epoch 00098: val_acc did not improve from 0.26812
# Epoch 99/500
#  - 7s - loss: 0.3881 - acc: 0.8597 - val_loss: 3.2543 - val_acc: 0.2633
#
# Epoch 00099: val_acc did not improve from 0.26812
# Epoch 100/500
#  - 7s - loss: 0.4067 - acc: 0.8585 - val_loss: 3.1520 - val_acc: 0.2440
#
# Epoch 00100: val_acc did not improve from 0.26812
# Epoch 101/500
#  - 7s - loss: 0.4165 - acc: 0.8669 - val_loss: 3.1709 - val_acc: 0.2512
#
# Epoch 00101: val_acc did not improve from 0.26812
# Epoch 102/500
#  - 7s - loss: 0.3586 - acc: 0.8730 - val_loss: 3.3002 - val_acc: 0.2271
#
# Epoch 00102: val_acc did not improve from 0.26812
# Epoch 103/500
#  - 7s - loss: 0.3977 - acc: 0.8663 - val_loss: 3.1491 - val_acc: 0.2319
#
# Epoch 00103: val_acc did not improve from 0.26812
# Epoch 104/500
#  - 7s - loss: 0.4166 - acc: 0.8585 - val_loss: 3.3890 - val_acc: 0.2343
#
# Epoch 00104: val_acc did not improve from 0.26812
# Epoch 105/500
#  - 7s - loss: 0.3889 - acc: 0.8724 - val_loss: 3.1186 - val_acc: 0.2415
#
# Epoch 00105: val_acc did not improve from 0.26812
# Epoch 106/500
#  - 7s - loss: 0.3623 - acc: 0.8766 - val_loss: 3.3749 - val_acc: 0.2391
#
# Epoch 00106: val_acc did not improve from 0.26812
# Epoch 107/500
#  - 7s - loss: 0.3506 - acc: 0.8808 - val_loss: 3.1120 - val_acc: 0.2536
#
# Epoch 00107: val_acc did not improve from 0.26812
# Epoch 108/500
#  - 7s - loss: 0.3324 - acc: 0.8784 - val_loss: 3.5086 - val_acc: 0.2391
#
# Epoch 00108: val_acc did not improve from 0.26812
# Epoch 109/500
#  - 7s - loss: 0.3179 - acc: 0.8940 - val_loss: 3.4552 - val_acc: 0.2174
#
# Epoch 00109: val_acc did not improve from 0.26812
# Epoch 110/500
#  - 7s - loss: 0.3608 - acc: 0.8790 - val_loss: 3.4153 - val_acc: 0.2053
#
# Epoch 00110: val_acc did not improve from 0.26812
# Epoch 111/500
#  - 7s - loss: 0.3509 - acc: 0.8814 - val_loss: 3.6535 - val_acc: 0.2150
#
# Epoch 00111: val_acc did not improve from 0.26812
# Epoch 112/500
#  - 7s - loss: 0.3732 - acc: 0.8724 - val_loss: 3.2010 - val_acc: 0.2319
#
# Epoch 00112: val_acc did not improve from 0.26812
# Epoch 113/500
#  - 7s - loss: 0.3586 - acc: 0.8808 - val_loss: 3.5151 - val_acc: 0.2319
#
# Epoch 00113: val_acc did not improve from 0.26812
# Epoch 114/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8d862c3c455e> in <module>()
#      11         #validation_split=VALIDATION_SPLIT,
#      12         validation_data=(X_test,y_test),
# ---> 13         callbacks=[tbCallBack,best_checkpoint])#,reduce_lr,esCallBack])
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1040                                         initial_epoch=initial_epoch,
#    1041                                         steps_per_epoch=steps_per_epoch,
# -> 1042                                         validation_steps=validation_steps)
#    1043
#    1044     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 if not isinstance(outs, list):
#     201                     outs = [outs]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
from keras.models import load_model
from sklearn.metrics import classification_report, confusion_matrix

modelLoaded = load_model('lstmCÑNROLL_new_data.h5', custom_objects={'CylindricalPadLSTMCNN2D':CylindricalPadLSTMCNN2D})

Y_pred_L = modelLoaded.predict(X_test)
y_pred_L = np.argmax(Y_pred_L, axis=1)

print('Confusion Matrix')
cm_CNN=confusion_matrix(np.argmax(y_test,axis=1), np.argmax(modelLoaded.predict(X_test),axis=1))
print(cm_CNN)



print(Y_pred_L.shape)
print(y_test.shape)
# Out:
# Confusion Matrix
# [[15 22  7 20  5]
#  [17 28  5 20 16]
#  [13 18  6 25 21]
#  [ 7 16 11 31 26]
#  [ 3 13  7 31 31]]
# (414, 5)
# (414, 5)

# %%
print(cm_CNN[0,0]+cm_CNN[0,1]+cm_CNN[1,0]+cm_CNN[1,1]+cm_CNN[3,3]+cm_CNN[3,4]+cm_CNN[4,3]+cm_CNN[4,4])
print(cm_CNN[3,0]+cm_CNN[3,1]+cm_CNN[4,0]+cm_CNN[4,1]+cm_CNN[0,3]+cm_CNN[0,4]+cm_CNN[1,3]+cm_CNN[1,4])

profit_CNN=(cm_CNN[0,0]+cm_CNN[0,1]+cm_CNN[1,0]+cm_CNN[1,1]+cm_CNN[3,3]+cm_CNN[3,4]+cm_CNN[4,3]+cm_CNN[4,4])-(cm_CNN[3,0]+cm_CNN[3,1]+cm_CNN[4,0]+cm_CNN[4,1]+cm_CNN[0,3]+cm_CNN[0,4]+cm_CNN[1,3]+cm_CNN[1,4])

print (profit_CNN)
# Out:
# 201
# 100
# 101
